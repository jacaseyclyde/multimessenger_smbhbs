# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(123)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_context("talk", font_scale=1.2)
sns.set_style('ticks')
sns.set_palette('colorblind')
figparams = {'font.family': 'DejaVu Sans',
             'font.serif':'Times',
             'text.latex.preamble': r'\usepackage{amsmath}',
             'text.usetex': True,
             'hatch.linewidth' : 3.0}
plt.rcParams.update(figparams)
cs = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# # The Generative Probabilistic Model

# %%
# Choose the "true" parameters.
log_phi_local = np.log10()

# %%
# Generate some synthetic data from the model.

# %%
sns.set_context("talk", font_scale=1.8)
fig = plt.figure(figsize=(12, 9))

label_fsize = 42
legend_fsize = 30

plt.hist(log_strain, histtype='step', density=True, color=cs[0], linestyle='-',
         weights=np.repeat(1 / len(log_strain), len(log_strain)), linewidth=2, fill=True, alpha=.2, hatch='/')
plt.hist(log_strain, histtype='step', density=True, color=cs[0], linestyle='-',
         weights=np.repeat(1 / len(log_strain), len(log_strain)), linewidth=2)

plt.axvline(log_strain_true, color='k', linestyle='--')
plt.xlabel(r'$\log A$', fontsize=label_fsize)

plt.tight_layout()
plt.show()
